# %%
import pandas as pd
import numpy as np
#from pandas_profiling import ProfileReport
#import seaborn as sns
import matplotlib.pyplot as plt

# for Q-Q plots
import scipy.stats as stats
# from feature-engine
# from feature-engine
from feature_engine.imputation import (
    AddMissingIndicator,
    MeanMedianImputer,
    CategoricalImputer,
)

import plotly.express as px
import plotly.graph_objs as go
from plotly.figure_factory import create_scatterplotmatrix
from plotly.subplots import make_subplots


# to split the datasets
from sklearn.model_selection import train_test_split
from sklearn.pipeline import Pipeline

# %%
X_train = pd.read_csv("Xtrain_tvshows.csv")
X_test = pd.read_csv("Xtest_tvshows.csv")
ytrain = pd.read_csv("ytrain_tvshows.csv")
ytest = pd.read_csv("ytest_tvshows.csv")
print("Shape of X Train: {}".format(X_train.shape))
print("Shape of X Test: {}".format(X_test.shape))
print("Shape of y Train: {}".format(ytrain.shape))
print("Shape of y Test: {}".format(ytest.shape))
# Out:
# Shape of X Train: (3757, 13)
# Shape of X Test: (1611, 13)
# Shape of y Train: (3757, 1)
# Shape of y Test: (1611, 1)

# %%
X_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3757 entries, 0 to 3756
# Data columns (total 13 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Unnamed: 0       3757 non-null   int64
#  1   ID               3757 non-null   int64
#  2   Title            3757 non-null   object
#  3   Year             3757 non-null   int64
#  4   Age              2274 non-null   object
#  5   IMDb             3092 non-null   object
#  6   Rotten Tomatoes  3757 non-null   object
#  7   Hulu             3757 non-null   int64
#  8   Prime Video      3757 non-null   int64
#  9   Disney+          3757 non-null   int64
#  10  Type             3757 non-null   int64
#  11  Age_na           3757 non-null   int64
#  12  IMDb_na          3757 non-null   int64
# dtypes: int64(9), object(4)
# memory usage: 381.7+ KB

# %%
data = [
    go.Histogram( x = X_train['Year'])
    ]

fig = go.Figure(data)
fig.update_xaxes(title_text='Jahr') #Achsen immer Beschriften
fig.update_yaxes(title_text='Anzahl Filme')
fig.show()
# Out:
# <div>                            <div id="3eb05df1-8fb9-4623-8005-1564c4b90c26" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("3eb05df1-8fb9-4623-8005-1564c4b90c26")) {                    Plotly.newPlot(                        "3eb05df1-8fb9-4623-8005-1564c4b90c26",                        [{"x":[2017,2019,1999,2007,2019,2017,2007,2011,1993,2019,2016,2005,2017,1977,2012,2018,2015,2020,2016,2020,2014,1995,2021,2016,2009,2009,2018,2016,2012,2017,2020,2004,2010,2010,1991,2017,2018,2013,2017,2017,2017,2008,2014,2019,2020,2014,2014,1997,2018,2010,1955,1980,2009,2015,1966,1932,2008,2016,2020,2013,2012,2007,2012,2019,2008,2018,1986,2020,2011,2005,1996,2019,2014,2016,2018,2013,2017,2016,2015,2012,2015,2017,2016,2012,2020,1996,2015,2015,2016,2017,2015,2010,2018,2020,2018,2018,1958,2014,2018,2012,2001,2020,2018,2016,2010,2014,2020,2017,2012,2018,2007,2021,2020,2018,2015,2021,2013,1988,2020,2008,2017,2017,2020,2011,1967,2019,2017,2019,2018,2017,1989,2019,2002,2019,2008,2020,2019,2019,2015,2017,2017,2005,2017,2002,2018,2017,2000,2021,2013,1994,2011,2011,2012,2018,2014,2014,2010,2014,2020,2010,2019,1996,2014,2021,2017,2016,2019,2014,1947,2017,2017,2019,2017,2010,2018,2014,2016,1988,2010,2019,